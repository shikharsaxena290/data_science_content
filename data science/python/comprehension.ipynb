# %%
l=[1,2,3,4,5]
l1=[]
for i in l:
  l1.append(i*i)
l1
# Out:
# [1, 4, 9, 16, 25]

# %%
l=[1,2,3,4,5]
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 25]

# %%
[i for i in l if i%2==0 ]
# Out:
# [2, 4]

# %%
l1=["shikhar","saxena","pwskills"]
[i.upper() for i in l1]
# Out:
# ['SHIKHAR', 'SAXENA', 'PWSKILLS']

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 25]

# %%
d={"k1":1,"k2":2,"k3":3,"k4":4}
{k:v**2 for k,v in d.items()}
# Out:
# {'k1': 1, 'k2': 4, 'k3': 9, 'k4': 16}
